# %% [markdown]
# # SWIGGY DATA ANALYSIS:

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# LOADING THE DATASET
df=pd.read_csv('swiggy.csv')

# %% [markdown]
# ## Data Dictionary
# * id-Every restraurant is having a UniqueID
# * name-Name of the Restaurant
# * city-The city where the restaurant is located
# * rating-Rating of the Restaurant
# * rating_count-Number of people given the Rating
# * cost-Cost of eating in the restaurant
# * cuisine-Cuisine that restaurant serves
# * lic_no-License number of that Restaurant
# * link-Restaurant link on Swiggy website
# * address-Full of the restaurant

# %%
df.head()
# Out:
#        id               name    city rating     rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     --  Too Few Ratings  ₹ 200
# 1  531342  Janta Sweet House  Abohar    4.4      50+ ratings  ₹ 200
# 2  158203  theka coffee desi  Abohar    3.8     100+ ratings  ₹ 100
# 3  187912          Singh Hut  Abohar    3.7      20+ ratings  ₹ 250
# 4  543530      GRILL MASTERS  Abohar     --  Too Few Ratings  ₹ 250
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# 4  https://www.swiggy.com/restaurants/grill-maste...
#
#                                              address              menu
# 0  AB FOODS POINT, NEAR RISHI NARANG DENTAL CLINI...  Menu/567335.json
# 1  Janta Sweet House, Bazar No.9, Circullar Road,...  Menu/531342.json
# 2         theka coffee desi, sahtiya sadan road city  Menu/158203.json
# 3    Singh Hut, CIRCULAR ROAD NEAR NEHRU PARK ABOHAR  Menu/187912.json
# 4  GRILL MASTERS, ADA Heights, Abohar - Hanumanga...  Menu/543530.json

# %%
df.tail()
# Out:
#             id                      name      city rating     rating_count  \
# 148536  553122          The Food Delight  Yavatmal     --  Too Few Ratings
# 148537  562647  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings
# 148538  559435           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings
# 148539  418989               GRILL ZILLA  Yavatmal     --  Too Few Ratings
# 148540  447770            Lazeez kitchen  Yavatmal     --  Too Few Ratings
#
#          cost           cuisine          lic_no  \
# 148536  ₹ 200  Fast Food,Snacks  21522053000452
# 148537  ₹ 300            Pizzas         license
# 148538  ₹ 300  Fast Food,Snacks  21522251000378
# 148539  ₹ 250       Continental  21521251000241
# 148540  ₹ 200            Pizzas  21521251000634
#
#                                                      link  \
# 148536  https://www.swiggy.com/restaurants/the-food-de...
# 148537  https://www.swiggy.com/restaurants/maitri-food...
# 148538  https://www.swiggy.com/restaurants/cafe-bella-...
# 148539  https://www.swiggy.com/restaurants/grill-zilla...
# 148540  https://www.swiggy.com/restaurants/lazeez-kitc...
#
#                                                   address              menu
# 148536  The Food Delight, 94MC+X35, New Singhania Naga...  Menu/553122.json
# 148537  MAITRI FOODS & BEVERAGES, POLIC MITRYA SOCIETY...  Menu/562647.json
# 148538  Cafe Bella Ciao, SHOP NO 2 NEMANI MARKET SBI S...  Menu/559435.json
# 148539  GRILL ZILLA, SHO NO 2/6, POSTEL GROUND CHOWPAT...  Menu/418989.json
# 148540  Lazeez kitchen, 94G3+2RR, Wadgaon, Yavatmal, M...  Menu/447770.json

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148541 entries, 0 to 148540
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            148541 non-null  int64
#  1   name          148455 non-null  object
#  2   city          148541 non-null  object
#  3   rating        148455 non-null  object
#  4   rating_count  148455 non-null  object
#  5   cost          148410 non-null  object
#  6   cuisine       148442 non-null  object
#  7   lic_no        148312 non-null  object
#  8   link          148541 non-null  object
#  9   address       148455 non-null  object
#  10  menu          148541 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 12.5+ MB

# %% [markdown]
# ## Possible Business Objective:
#
# *How do I Increase my business?
# 1. Which cuisine is most  profitable?
# 2. Which is the most popular Cuisine?
# 3. Which is the most profitable?

# %% [markdown]
# ## Possible PreProcessing
#
# * Remove rupee symbol in  cost
# * Convert rating to numeric (handle--)
# * Remove null values - cost
# * Handle rating_count(convert to numeric)
# * Handle cuisine(split?)

# %% [markdown]
# ## Possible EDA
#
# * What is the count of cities?
# * Top n restaurants with higest ratings
# * Top n cities with highest cost
# * Top n cities with n cussines

# %% [markdown]
# ## Preprocessing:

# %%
df.isna().sum()
# Out:
# id                0
# name             86
# city              0
# rating           86
# rating_count     86
# cost            131
# cuisine          99
# lic_no          229
# link              0
# address          86
# menu              0
# dtype: int64

# %% [markdown]
#  Removing null rows:

# %%
df=df.dropna()
df.isna().sum()
# Out:
# id              0
# name            0
# city            0
# rating          0
# rating_count    0
# cost            0
# cuisine         0
# lic_no          0
# link            0
# address         0
# menu            0
# dtype: int64

# %% [markdown]
#     HANDLING NULL RATINGS:

# %%
df['rating'].replace('--',np.nan,inplace=True)
# df['rating'].fillna(df['rating'].median(),inplace=True)
df['rating'].fillna(-999.0,inplace=True)
df['rating']=df['rating'].astype(float)

# %% [markdown]
#     HANDLING CATEGORICAL COUNT OF RATINGS:

# %%
""" from sklearn import preprocessing

label_encoder=preprocessing.label_encoder()
df['rating_count']=label_encoder.fit_transform(df['rating_count'])

df.head() """

# %% [markdown]
#     HANDLING SPECIAL SYMBOL IN COST(FOR TWO):

# %%
df['cost']=df['cost'].str[1:].astype(float)
df.head()
# Out:
#        id               name    city  rating     rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar  -999.0  Too Few Ratings  200.0
# 1  531342  Janta Sweet House  Abohar     4.4      50+ ratings  200.0
# 2  158203  theka coffee desi  Abohar     3.8     100+ ratings  100.0
# 3  187912          Singh Hut  Abohar     3.7      20+ ratings  250.0
# 4  543530      GRILL MASTERS  Abohar  -999.0  Too Few Ratings  250.0
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# 4  https://www.swiggy.com/restaurants/grill-maste...
#
#                                              address              menu
# 0  AB FOODS POINT, NEAR RISHI NARANG DENTAL CLINI...  Menu/567335.json
# 1  Janta Sweet House, Bazar No.9, Circullar Road,...  Menu/531342.json
# 2         theka coffee desi, sahtiya sadan road city  Menu/158203.json
# 3    Singh Hut, CIRCULAR ROAD NEAR NEHRU PARK ABOHAR  Menu/187912.json
# 4  GRILL MASTERS, ADA Heights, Abohar - Hanumanga...  Menu/543530.json

# %% [markdown]
# ## Exploratory  Analysis:

# %% [markdown]
#     How many cities does Swiggy serve?

# %%
df.city.nunique()
# Out:
# 821

# %% [markdown]
#     How many restaurants are within Swiggy's purview?

# %%
df.name.nunique()
# Out:
# 112683

# %%
df.id.nunique()
# Out:
# 148255

# %% [markdown]
#     What are the most popular food chains?

# %%
df.name.value_counts().head(5)
# Out:
# name
# Domino's Pizza                                     442
# Pizza Hut                                          319
# KFC                                                309
# Kwality Walls Frozen Dessert and Ice Cream Shop    299
# Baskin Robbins                                     274
# Name: count, dtype: int64

# %% [markdown]
#     What is the rating distribution?

# %%
df.rating.value_counts()
# Out:
# rating
# -999.0    86912
#  4.0       6524
#  4.1       6288
#  4.2       5811
#  3.8       5728
#  3.9       5428
#  4.3       5005
#  3.7       4239
#  4.4       3145
#  3.5       2958
#  3.6       2918
#  3.4       1878
#  3.3       1796
#  4.5       1775
#  4.6       1332
#  3.2       1199
#  3.0        858
#  3.1        790
#  4.7        648
#  2.8        473
#  2.9        471
#  4.8        338
#  2.7        325
#  2.5        220
#  5.0        209
#  2.6        207
#  4.9        172
#  2.3        128
#  2.4        118
#  2.2         89
#  2.0         72
#  2.1         61
#  1.9         46
#  1.8         27
#  1.5         18
#  1.6         17
#  1.7         13
#  1.4         10
#  1.2          4
#  1.3          3
#  1.1          1
#  1.0          1
# Name: count, dtype: int64

# %%
df.rating.value_counts().sort_index()
# Out:
# rating
# -999.0    86912
#  1.0          1
#  1.1          1
#  1.2          4
#  1.3          3
#  1.4         10
#  1.5         18
#  1.6         17
#  1.7         13
#  1.8         27
#  1.9         46
#  2.0         72
#  2.1         61
#  2.2         89
#  2.3        128
#  2.4        118
#  2.5        220
#  2.6        207
#  2.7        325
#  2.8        473
#  2.9        471
#  3.0        858
#  3.1        790
#  3.2       1199
#  3.3       1796
#  3.4       1878
#  3.5       2958
#  3.6       2918
#  3.7       4239
#  3.8       5728
#  3.9       5428
#  4.0       6524
#  4.1       6288
#  4.2       5811
#  4.3       5005
#  4.4       3145
#  4.5       1775
#  4.6       1332
#  4.7        648
#  4.8        338
#  4.9        172
#  5.0        209
# Name: count, dtype: int64

# %%
rating_df=100 * df.rating.value_counts().sort_index()/len(df)
rating_df=rating_df.reset_index()
rating_df.columns=['rating','percentage']
rating_df['rating']=rating_df['rating'].astype(str)
rating_df.head()
# Out:
#    rating  percentage
# 0  -999.0   58.623318
# 1     1.0    0.000675
# 2     1.1    0.000675
# 3     1.2    0.002698
# 4     1.3    0.002024

# %%
rating_df.plot(x='rating',y='percentage',alpha=0.5);

# %%
rating_df=rating_df.tail(-1)
rating_df.plot(x='rating',y='percentage',alpha=0.5)
# Out:
# <Axes: xlabel='rating'>

# %% [markdown]
#     Which city had the most restaurants?

# %%
# dataframe -> split it by city into 821 smaller dataframes -> get the id column from each dataframe -> count the unique ids ->
# -> city, unique_count (821 dataframes) -> combine them -> sort -> top 20
df.groupby(['city'])['id'].nunique().sort_values(ascending=False).head(20)
# Out:
# city
# Bikaner                      1665
# Noida-1                      1424
# Indirapuram,Delhi            1279
# BTM,Bangalore                1159
# Rohini,Delhi                 1135
# Kothrud,Pune                 1086
# Indiranagar,Bangalore        1079
# Electronic City,Bangalore    1039
# Greater Kailash 2,Delhi      1037
# Vashi,Mumbai                 1021
# Kukatpally,Hyderabad         1008
# Viman Nagar,Pune             1000
# sohna road,Gurgaon            973
# Koramangala,Bangalore         953
# Laxmi Nagar,Delhi             930
# Gomti Nagar,Lucknow           915
# HSR,Bangalore                 898
# Malviya Nagar,Delhi           896
# Madhapur,Hyderabad            892
# Wakad,Pune                    868
# Name: id, dtype: int64

# %% [markdown]
#     Which city has the best food?

# %%
print(df['rating_count'].nunique())
# Out:
# 8

# %%
# city with best retaurants
sub1=df[df['rating_count'].isin(['100+ ratings','500+ ratings','1K+ ratings','5K+ ratings','10K+ ratings'])]
sub1.head()
# Out:
#         id                    name      city  rating  rating_count   cost  \
# 2   158203       theka coffee desi    Abohar     3.8  100+ ratings  100.0
# 6   156588        shere punjab veg    Abohar     4.0  100+ ratings  150.0
# 38  351387         NIKKU VEG THALI    Abohar     4.1  100+ ratings  150.0
# 63  165533          IFC Restaurant  Adilabad     3.5  100+ ratings  400.0
# 65  242943  Hot N Chill Restaurant  Adilabad     3.5  100+ ratings  150.0
#
#              cuisine          lic_no  \
# 2          Beverages  22121652000190
# 6       North Indian  22120652000021
# 38      North Indian  22121652000183
# 63          American  13619001000093
# 65  European,Italian  13619001000192
#
#                                                  link  \
# 2   https://www.swiggy.com/restaurants/theka-coffe...
# 6   https://www.swiggy.com/restaurants/shere-punja...
# 38  https://www.swiggy.com/restaurants/nikku-veg-t...
# 63  https://www.swiggy.com/restaurants/ifc-restaur...
# 65  https://www.swiggy.com/restaurants/hot-n-chill...
#
#                                               address              menu
# 2          theka coffee desi, sahtiya sadan road city  Menu/158203.json
# 6   shere punjab veg, major surinder chowk near ve...  Menu/156588.json
# 38  NIKKU VEG THALI, College Road, Near Railway Li...  Menu/351387.json
# 63  IFC Restaurant, Jagadamba Towers, Gandhi Print...  Menu/165533.json
# 65  Hot N Chill Restaurant, H NO 4 -4 -703 BHUKTHA...  Menu/242943.json

# %%
sub2=sub1[sub1['rating']>=4.8]

# %%
sub2
# Out:
#             id                                               name  \
# 8710    332602    Kwality Walls Frozen Dessert and Ice Cream Shop
# 10012   286156                                         SOUR HOUSE
# 10766   446568                               Dairy Day Ice Creams
# 13491   Senoritas Mexican kitchen by Little Italy, No....  Menu/383734.json
# 14164   Omm Nom Nomm, Villa A 101, Victorian View, Beh...  Menu/237229.json
# 17471   Brahmins Thatte idli, 2G28+675, Doddanna Indus...  Menu/537526.json
# 24366   Ram Fast Food, Handaya bazar, ram bagh de back...  Menu/161311.json
# 35066   Kwality Walls Frozen Dessert and Ice Cream Sho...  Menu/310943.json
# 48529   Kwality Walls Frozen Dessert and Ice Cream Sho...  Menu/309376.json
# 51467   Blue Tokai Coffee Roasters, M-71, Ground Floor...  Menu/217386.json
# 64713   Chhaswala, Shop no 18, Real prime, Bapa sitara...  Menu/509023.json
# 64719   Anmol Bhel House, NEW NEHRU NAGAR, 80 FT MAIN ...  Menu/459750.json
# 64775   Krishna Candy, 3-4, Silver Complex, Opp.Big Ba...  Menu/208823.json
# 67267   Kwality Walls Frozen Dessert and Ice Cream Sho...  Menu/330540.json
# 74743   Govi's Organic Foods, H.no. 6-3-609/170, anand...  Menu/259810.json
# 80593   A1 NAAN MAHAL, 8-1-31,VIRAT NAGAR,TOLICHOWKI,H...  Menu/478227.json
# 83634   Mahi Bakery, 77/98 MANSAROVAR JAIPUR , Jaipur-...  Menu/509057.json
# 83799   Tony Bakery, 33b kharbas path shiv Vatika maga...  Menu/513786.json
# 83813   Aaradhya cafe and fast food, 51,luv kush nagar...  Menu/512200.json
# 87596   SHRI KRISHNA FOOD ZONE, VIVEKANAND CHOAK LAKHE...  Menu/526984.json
# 88805   Natural Ice Cream, Atharva, 4th dimention , ne...  Menu/124943.json
# 89603        Mithai, 18, Gariahat Road, Gariahat, Kolkata  Menu/120944.json
# 89613   Natural Ice Cream, P-563, LAKE ROAD(HEMANTA MU...  Menu/326540.json
# 93947   Natural Ice Cream, Shop No 77/1A, Park Street,...   Menu/37107.json
# 94854   Grameen Kulfi, NIC NATURAL SHOP NO: 25/A, RAJA...  Menu/386631.json
# 95769   Pabrai's Fresh and Naturelle Ice Cream, Shop 2...   Menu/61773.json
# 95973   Kwality Walls Frozen Dessert and Ice Cream Sho...  Menu/510326.json
# 96388   Pabrai's Fresh And Naturelle Ice Cream - Jodhp...  Menu/320887.json
# 96786   MOMO CIRCLE, 15,N.S.C. BOSE ROAD,GROUND FLOOR,...  Menu/317332.json
# 102268  Kwality Walls Frozen Dessert and Ice Cream Sho...  Menu/363536.json
# 103353    Jain Tiffin Center, Abhinandan colony, Mandsaur  Menu/199911.json
# 103833  Grameen Kulfi, NIC NATURAL ICECREAMS -PLOT NO ...  Menu/367817.json
# 105275  CAFE 99, MALL GODAM ROAD, NEAR PUNJAB AND SIND...  Menu/428825.json
# 107319  Natural Ice Cream, 28/A, Happy Home CHS, Opp. ...   Menu/30897.json
# 107361  Country of Origin, 69 A, Nepean Sea Road, Mani...   Menu/65688.json
# 107855  Grameen Kulfi, Shop No-01, Room No-201, Ground...  Menu/351117.json
# 109597  Blue Tokai Coffee Roasters, Ground Floor, Bloc...   Menu/57231.json
# 113710  Shrikhandwala, Vitthal Rukhmini Complex, Upper...  Menu/100564.json
# 115498  Grameen Kulfi, H No. 11-1-1769/1 Maruti Nagar ...  Menu/355758.json
# 118207  Baskin Robbins, Baskin Robbins, 1, Bharadwaj H...   Menu/84377.json
# 128372  Grameen Kulfi, Nic Natural Ice Creams, Shop No...  Menu/352810.json
# 135613  SUNSHINE SHAKE, WH4X+PMX, Azad Garh, Rajendra ...  Menu/467010.json

# %%
sub2.city.value_counts()
# Out:
# city
# Manasarovar,Jaipur               3
# Gondal                           3
# South Kolkata,Kolkata            2
# Jadavpur,Kolkata                 2
# Mahalaxmi Malabar Hill,Mumbai    2
# Mansa                            1
# Lake Town,Kolkata                1
# Dumdum,Kolkata                   1
# Dugri,Ludhiana                   1
# Mandsaur                         1
# Muktsar                          1
# Central Kolkata,Kolkata          1
# Vashi,Mumbai                     1
# Scruz Bandra East,Mumbai         1
# Bajaj Nagar,Nagpur               1
# Nizamabad                        1
# North-goa                        1
# Hinjewadi,Pune                   1
# Behala,Kolkata                   1
# Balurghat                        1
# Koramangala,Bangalore            1
# Kolhapur                         1
# Katni                            1
# Tolichowki,Hyderabad             1
# Banjara Hills,Hyderabad          1
# Old Gurgaon (Zone 6),Gurgaon     1
# Greater Kailash 2,Delhi          1
# Jasola,Delhi                     1
# Annanagar,Chennai                1
# Barnala                          1
# Basaveshwaranagar,Bangalore      1
# Whitefield,Bangalore             1
# Indiranagar,Bangalore            1
# Arekere,Bangalore                1
# JP Nagar,Bangalore               1
# Rohtak                           1
# Name: count, dtype: int64

# %% [markdown]
#     What is the cost distribution?

# %%
df.cost.sort_values(ascending=False)
# Out:
# 70762     300350.0
# 21626       8000.0
# 47552       6000.0
# 47817       5023.0
# 107779      5000.0
#             ...
# 94098          1.0
# 109636         1.0
# 121078         1.0
# 148236         1.0
# 43814          1.0
# Name: cost, Length: 148255, dtype: float64

# %%
df.cost.plot()
# Out:
# <Axes: >

# %%
np.argmax(df['cost'])
# Out:
# 70642

# %%
df.iloc[70642]
# Out:
# id                                                         477718
# name                                               KOHINOOR HOTEL
# city                                                   Hinganghat
# rating                                                     -999.0
# rating_count                                      Too Few Ratings
# cost                                                     300350.0
# cuisine                                      North Indian,Chinese
# lic_no                                             21521269001428
# link            https://www.swiggy.com/restaurants/kohinoor-ho...
# address         KOHINOOR HOTEL, LIBOURY CHOWK TAKA GROUND NR-B...
# menu                                             Menu/477718.json
# Name: 70762, dtype: object

# %%
df=df[df['id']!=477718]

# %%
df.cost.plot()
# Out:
# <Axes: >

# %% [markdown]
#     What are the most Expensive places?

# %%
df.sort_values(by='cost',ascending=False).head(20)
# Out:
#             id                            name  \
# 21626   456114                Oasis restaurant
# 47552   565958          VENOM CLUB AND KITCHEN
# 47817   524995            Aggarwal sweet india
# 107779  564511                SHAAN RESTAURANT
# 4930    579304       Rock N Shawarma Take Away
# 109414  369682        Ministry of Crab, Mumbai
# 23334   477654                     Olive Beach
# 76454   469411                      SRS HAVMOR
# 75847   471229                Sofra food court
# 93507   312816                            SKAI
# 74961   577851         THE KING STREET  BAKERS
# 70387   521165                   Shree Rathnam
# 23334   https://www.swiggy.com/restaurants/olive-beach...
# 76454   https://www.swiggy.com/restaurants/srs-havmor-...
# 75847   https://www.swiggy.com/restaurants/sofra-food-...
# 93507   https://www.swiggy.com/restaurants/skai-centra...
# 74961   https://www.swiggy.com/restaurants/the-king-st...
# 70387   https://www.swiggy.com/restaurants/shree-rathn...
# 43861   https://www.swiggy.com/restaurants/koox-roofto...
# 145836  https://www.swiggy.com/restaurants/chikn-n-gri...
# 53026   https://www.swiggy.com/restaurants/dilli-kante...
# 106368  https://www.swiggy.com/restaurants/gourmet-cou...
# 13626   https://www.swiggy.com/restaurants/dfc-kitchen...
# 53027   https://www.swiggy.com/restaurants/cascades-th...
# 108400  https://www.swiggy.com/restaurants/mynt-vivant...
# 93509   https://www.swiggy.com/restaurants/serafina-ce...
#
#                                                   address              menu
# 21626   Oasis restaurant, Neeladri Road, Karuna Nagar,...  Menu/456114.json
# 47552   VENOM CLUB AND KITCHEN, 1st & 2nd Floor , 76/5...  Menu/565958.json
# 47817   Aggarwal sweet india, 199, Stadium Rd, Block A...  Menu/524995.json
# 107779  SHAAN RESTAURANT, SHOP NO. 1, G SQUARE BUSINES...  Menu/564511.json
# 4930    Rock N Shawarma Take Away, NEAR HINDUSTAN MACH...  Menu/579304.json
# 109414  Ministry of Crab, Mumbai, 442, Chitrakar Dhura...  Menu/369682.json
# 23334   Olive Beach, 16, Wood St, near Karnataka Bank,...  Menu/477654.json
# 76454   SRS HAVMOR, H No: 9-5-1/B/2, Near Bhashyam Blo...  Menu/469411.json
# 75847   Sofra food court, 5-5-708/8, Udayanandan Heigh...  Menu/471229.json
# 93507   SKAI, 33, Syed Amir Ali Avenue, Quest Mall, 4t...  Menu/312816.json
# 74961   THE KING STREET  BAKERS, 8-2-293/44, s.v nagar...  Menu/577851.json
# 70387   Shree Rathnam, ARJUN NAGAR GATE, OPP SSV INTER...  Menu/521165.json
# 43861   KooX - Rooftop Asian Grill, Novotel Chennai Ch...  Menu/293932.json
# 145836  CHIKN N GRILL, 56-2-14/1 , Vijayawada (Urban),...  Menu/550751.json
# 53026   Dilli Kanteen Kitchen, Nelson Mandela Road,  V...  Menu/475991.json
# 106368  Gourmet Couch By ITC Maratha, ITC Maratha, Sah...  Menu/294454.json
# 13626    DFC KITCHEN, Domlur, Bengaluru, Karnataka, India  Menu/439995.json
# 53027   Cascades - The Grand New Delhi, Nelson Mandela...  Menu/472240.json
# 108400  Mynt - Vivanta, VIVANTA - NAVI MUMBAI PLOT NO ...  Menu/565948.json
# 93509   Serafina, 33, Syed Amir Ali Avenue, 5th Floor,...  Menu/312817.json

# %% [markdown]
#     What are the most cuisine types?

# %%
sub3=df[df['rating']>3.5]
len(sub3)
# Out:
# 49560

# %%
sub3.cuisine.nunique()
# Out:
# 1530

# %%
sub3.cuisine.value_counts(ascending=False)
# Out:
# cuisine
# North Indian,Chinese     2191
# South Indian             1439
# Indian                   1412
# Indian,Chinese           1389
# North Indian             1372
#                          ...
# Awadhi,Lucknowi             1
# Thalis,Tandoor              1
# Persian,Arabian             1
# Indian,Kashmiri             1
# South American,Andhra       1
# Name: count, Length: 1530, dtype: int64

# %%
# Another way of doing the same thing
cuisine_list = sub3.cuisine.tolist()
len(cuisine_list)
# Out:
# 49560

# %%
split_cuisine_list = [y.lower() for x in cuisine_list for y in x.split(',')]
len(split_cuisine_list)
# Out:
# 87645

# %%
from collections import Counter
cuisine_frequency = Counter(split_cuisine_list)

# %%
cuisine_frequency
# Out:
# Counter({'north indian': 11584,
#          'chinese': 10680,
#          'indian': 6427,
#          'desserts': 5555,
#          'south indian': 5357,
#          'biryani': 4771,
#          'beverages': 4500,
#          'snacks': 4108,
#          'fast food': 3094,
#          'pizzas': 3067,
#          'bakery': 2887,
#          'ice cream': 2783,
#          'italian': 1912,
#          'american': 1839,
#          'continental': 1610,
#          'sweets': 1420,
#          'mughlai': 1391,
#          'punjabi': 1044,
#          'healthy food': 1035,
#          'arabian': 880,
#          'tandoor': 729,
#          'asian': 717,
#          'street food': 594,
#          'salads': 535,
#          'juices': 524,
#          'chaat': 521,
#          'thalis': 477,
#          'bengali': 464,
#          'tibetan': 408,
#          'thai': 399,
#          'mexican': 391,
#          'pastas': 372,
#          'andhra': 352,
#          'burgers': 348,
#          'hyderabadi': 333,
#          'maharashtrian': 329,
#          'kebabs': 327,
#          'barbecue': 316,
#          'seafood': 308,
#          'kerala': 307,
#          'lebanese': 265,
#          'pan-asian': 245,
#          'home food': 243,
#          'combo': 212,
#          'chettinad': 187,
#          'gujarati': 167,
#          'grill': 121,
#          'japanese': 110,
#          'italian-american': 109,
#          'european': 95,
#          'rajasthani': 91,
#          'waffle': 75,
#          'oriental': 60,
#          'keto': 57,
#          'cafe': 55,
#          'goan': 55,
#          'sushi': 48,
#          'mediterranean': 47,
#          'afghani': 46,
#          'coastal': 43,
#          'jain': 42,
#          'middle eastern': 41,
#          'paan': 39,
#          'ice cream cakes': 37,
#          'mangalorean': 33,
#          'burmese': 32,
#          'turkish': 25,
#          'nepalese': 23,
#          'bihari': 23,
#          'korean': 22,
#          'french': 20,
#          'lucknowi': 19,
#          'malwani': 19,
#          'naga': 18,
#          'oriya': 17,
#          'assamese': 17,
#          'north eastern': 16,
#          'bangladeshi': 16,
#          'awadhi': 14,
#          'portuguese': 12,
#          'african': 11,
#          'malaysian': 10,
#          'parsi': 10,
#          'british': 9,
#          'singaporean': 8,
#          'haleem': 8,
#          'steakhouse': 7,
#          'kashmiri': 7,
#          'indonesian': 6,
#          'vietnamese': 6,
#          'rayalaseema': 6,
#          'german': 5,
#          'spanish': 5,
#          'sindhi': 5,
#          'greek': 4,
#          'persian': 3,
#          'konkan': 3,
#          'tex-mex': 3,
#          'south american': 3,
#          'tribal': 2,
#          'telangana': 2,
#          'attractive combos available': 1,
#          'code valid on bill over rs.99': 1,
#          'svanidhi street food vendor': 1,
#          'australian': 1,
#          'navratri special': 1,
#          'bhutanese': 1,
#          'discount offer from garden cafe express kankurgachi': 1,
#          'use code xpress121 to avail.': 1,
#          'special discount from (hotel swagath)': 1,
#          'tandoor ': 1,
#          'khasi': 1})
